# %% [markdown]
# # Grabbing IOP data

# %%
import earthaccess

# %% [markdown]
# # Authorize

# %%
auth = earthaccess.login(persist=True)

# %% [markdown]
# # Prep

# %%
results = earthaccess.search_datasets(instrument="oci")

for item in results:
    summary = item.summary()
    print(summary["short-name"])
# Out:
# PACE_OCI_L1B_SCI
# PACE_OCI_L2_AOP_NRT
# PACE_OCI_L2_AER_UAA
# PACE_OCI_L2_AOP
# PACE_OCI_L2_BGC_NRT
# PACE_OCI_L3M_CHL_NRT
# PACE_OCI_L2_BGC
# PACE_OCI_L2_CLOUD_MASK
# PACE_OCI_L2_SFREFL_NRT
# PACE_OCI_L3M_CHL
# PACE_OCI_L1C_SCI
# PACE_OCI_L2_CLOUD
# PACE_OCI_L3M_RRS
# PACE_OCI_L2_CLOUD_NRT
# PACE_OCI_L2_IOP
# PACE_OCI_L2_SFREFL
# PACE_OCI_L2_UVAI_UAA_NRT
# PACE_OCI_L3M_AER_UAA_NRT
# PACE_OCI_L3M_CLOUD
# PACE_OCI_L4M_MOANA
# PACE_OCI_L2_AER_UAA_NRT
# PACE_OCI_L2_CLOUD_MASK_NRT
# PACE_OCI_L2_IOP_NRT
# PACE_OCI_L2_LANDVI
# PACE_OCI_L2_PAR
# PACE_OCI_L2_PAR_NRT
# PACE_OCI_L2_UVAI_UAA
# PACE_OCI_L3B_CHL
# PACE_OCI_L3B_CHL_NRT
# PACE_OCI_L3M_AER_UAA
# PACE_OCI_L3M_CLOUD_NRT
# PACE_OCI_L3M_IOP_NRT
# PACE_OCI_L3M_LANDVI
# PACE_OCI_L4M_MOANA_NRT
# PACE_OCI_L0_SCI
# PACE_OCI_L1A_SCI
# PACE_OCI_L2_LANDVI_NRT
# PACE_OCI_L3B_AVW
# PACE_OCI_L3B_AVW_NRT
# PACE_OCI_L3B_CARBON
# PACE_OCI_L3B_CARBON_NRT
# PACE_OCI_L3B_FLH
# PACE_OCI_L3B_FLH_NRT
# PACE_OCI_L3B_IOP
# PACE_OCI_L3B_IOP_NRT
# PACE_OCI_L3B_KD
# PACE_OCI_L3B_KD_NRT
# PACE_OCI_L3B_LANDVI
# PACE_OCI_L3B_LANDVI_NRT
# PACE_OCI_L3B_PAR
# PACE_OCI_L3B_PAR_NRT
# PACE_OCI_L3B_POC
# PACE_OCI_L3B_POC_NRT
# PACE_OCI_L3B_RRS
# PACE_OCI_L3B_RRS_NRT
# PACE_OCI_L3B_SFREFL
# PACE_OCI_L3B_SFREFL_NRT
# PACE_OCI_L3M_AVW
# PACE_OCI_L3M_AVW_NRT
# PACE_OCI_L3M_CARBON
# PACE_OCI_L3M_CARBON_NRT
# PACE_OCI_L3M_FLH
# PACE_OCI_L3M_FLH_NRT
# PACE_OCI_L3M_IOP
# PACE_OCI_L3M_KD
# PACE_OCI_L3M_KD_NRT
# PACE_OCI_L3M_LANDVI_NRT
# PACE_OCI_L3M_PAR
# PACE_OCI_L3M_PAR_NRT
# PACE_OCI_L3M_POC
# PACE_OCI_L3M_POC_NRT
# PACE_OCI_L3M_RRS_NRT
# PACE_OCI_L3M_SFREFL
# PACE_OCI_L3M_SFREFL_NRT

# %% [markdown]
# # Grab IOP

# %%
results = earthaccess.search_data(
    short_name="PACE_OCI_L2_IOP",
    count=1,
)

# %%
results
# Out:
# [Collection: {'ShortName': 'PACE_OCI_L2_IOP', 'Version': '3.1'}
#  Spatial coverage: {'HorizontalSpatialDomain': {'Geometry': {'GPolygons': [{'Boundary': {'Points': [{'Latitude': 55.53328, 'Longitude': -158.936}, {'Latitude': 48.9575, 'Longitude': 162.20712}, {'Latitude': 32.2551, 'Longitude': 172.73434}, {'Latitude': 37.77998, 'Longitude': -158.38428}, {'Latitude': 55.53328, 'Longitude': -158.936}]}}]}}}
#  Temporal coverage: {'RangeDateTime': {'EndingDateTime': '2024-03-05T00:13:57Z', 'BeginningDateTime': '2024-03-05T00:08:58Z'}}
#  Size(MB): 38.588480949401855
#  Data: ['https://obdaac-tea.earthdatacloud.nasa.gov/ob-cumulus-prod-public/PACE_OCI.20240305T000858.L2.OC_IOP.V3_1.nc']]
